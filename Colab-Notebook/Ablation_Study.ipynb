# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Master Thesis/ultralytics'
# Out:
# /content/drive/.shortcut-targets-by-id/1cJcJ_IZb_6BgXKcitj-rgkK17xQwujX2/Master Thesis/ultralytics

# %%
from ultralytics import YOLO

# %%
model_batch32=YOLO('yolov8n.yaml')
model_batch32.train(data='data-cfg/dsdd.yaml', epochs=20, batch=32, name='batch32')
# Out:
# New https://pypi.org/project/ultralytics/8.2.34 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...

# %%
model_dropout=YOLO('yolov8n.yaml')
model_dropout.train(data='data-cfg/dsdd.yaml', epochs=20, dropout= 0.2, name='dropout')
# Out:
# New https://pypi.org/project/ultralytics/8.2.34 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...

# %%
model_small=YOLO('yolov8s.yaml')
model_small.train(data='data-cfg/dsdd.yaml', epochs=20, name='smallv2')
# Out:
# New https://pypi.org/project/ultralytics/8.2.34 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model_ca21=YOLO('yolov8n-ca21.yaml')
model_ca21.train(data='data-cfg/dsdd.yaml', epochs=20, name='ca21')
# Out:
# New https://pypi.org/project/ultralytics/8.2.35 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model_ca25=YOLO('yolov8n-ca25.yaml')
model_ca25.train(data='data-cfg/dsdd.yaml', epochs=20, name='ca25')
# Out:
# New https://pypi.org/project/ultralytics/8.2.35 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model_eca21=YOLO('yolov8n-eca21.yaml')
model_eca21.train(data='data-cfg/dsdd.yaml', epochs=20, name='eca21')
# Out:
# New https://pypi.org/project/ultralytics/8.2.35 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model_eca25=YOLO('yolov8n-eca25.yaml')
model_eca25.train(data='data-cfg/dsdd.yaml', epochs=20, name='eca25')
# Out:
# New https://pypi.org/project/ultralytics/8.2.35 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model_sp=YOLO('yolov8n-sppf.yaml')
model_sp.train(data='data-cfg/dsdd.yaml', epochs=20, name='sppf')
# Out:
# New https://pypi.org/project/ultralytics/8.2.35 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model_ca_sp=YOLO('yolov8n-ca-sppf.yaml')
model_ca_sp.train(data='data-cfg/dsdd.yaml', epochs=20, name='ca-sppf')
# Out:
# New https://pypi.org/project/ultralytics/8.2.35 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model_eca_sp=YOLO('yolov8n-eca-sppf.yaml')
model_eca_sp.train(data='data-cfg/dsdd.yaml', epochs=20, name='eca-sppf')
# Out:
# New https://pypi.org/project/ultralytics/8.2.35 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model_small=YOLO('yolov8s.yaml')
model_small.train(data='data-cfg/dsdd.yaml', epochs=20, name='smallv3')
# Out:
# New https://pypi.org/project/ultralytics/8.2.35 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
#Mixed ECA
model_eca=YOLO('yolov8n-ECA.yaml')
model_eca.train(data='data-cfg/Mixed-train.yaml', epochs=20)
# Out:
# New https://pypi.org/project/ultralytics/8.2.36 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
