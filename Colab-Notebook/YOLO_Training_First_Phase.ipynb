# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Master Thesis/ultralytics'
# Out:
# /content/drive/MyDrive/Master Thesis/ultralytics

# %%
# %pycat /root/.config/Ultralytics/settings.yaml

# %%
from ultralytics import YOLO

# %%
model=YOLO('yolov8n.yaml')
model.train(data='data-cfg/dsdd.yaml', epochs=20)
# Out:
# New https://pypi.org/project/ultralytics/8.2.5 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model_ca=YOLO('yolov8n-CA.yaml')
model_ca.train(data='data-cfg/dsdd.yaml', epochs=20)
# Out:
# New https://pypi.org/project/ultralytics/8.2.5 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model_eca=YOLO('yolov8n-ECA.yaml')
model_eca.train(data='data-cfg/dsdd.yaml', epochs=20)
# Out:
# New https://pypi.org/project/ultralytics/8.2.5 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
