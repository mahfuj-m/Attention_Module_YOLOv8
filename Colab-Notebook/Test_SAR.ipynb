# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Master Thesis/ultralytics'
# Out:
# /content/drive/.shortcut-targets-by-id/1cJcJ_IZb_6BgXKcitj-rgkK17xQwujX2/Master Thesis/ultralytics

# %%
from ultralytics import YOLO

# %%
#Baseline Testing

# %%
model=YOLO('runs/detect/train19/weights/best.pt')
model.val(data="data-cfg/test-hh.yaml")
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients
# val: Scanning /content/drive/.shortcut-targets-by-id/1cJcJ_IZb_6BgXKcitj-rgkK17xQwujX2/Master Thesis/ultralytics/Datasets/SAR-Ship/HH/labels.cache... 17648 images, 0 backgrounds, 0 corrupt: 100%|██████████| 17648/17648 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1103/1103 [07:44<00:00,  2.38it/s]
#                    all      17648      21334      0.673      0.591       0.64      0.241
# Speed: 0.3ms preprocess, 3.9ms inference, 0.0ms loss, 1.9ms postprocess per image
# Results saved to runs/detect/val
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7c9407d77520>
# ...

# %%
model.val(data="data-cfg/test-hv.yaml")
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/drive/.shortcut-targets-by-id/1cJcJ_IZb_6BgXKcitj-rgkK17xQwujX2/Master Thesis/ultralytics/Datasets/SAR-Ship/HV/labels.cache... 14713 images, 10 backgrounds, 0 corrupt: 100%|██████████| 14723/14723 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|█████████▉| 920/921 [45:10<00:03,  3.11s/it]/usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 921/921 [45:10<00:00,  2.94s/it]
# ...

# %%
model.val(data="data-cfg/test-vh.yaml")
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/drive/.shortcut-targets-by-id/1cJcJ_IZb_6BgXKcitj-rgkK17xQwujX2/Master Thesis/ultralytics/Datasets/SAR-Ship/VH/labels.cache... 3764 images, 0 backgrounds, 0 corrupt: 100%|██████████| 3764/3764 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 236/236 [01:38<00:00,  2.40it/s]
#                    all       3764       5608      0.515      0.466      0.452      0.156
# Speed: 0.5ms preprocess, 4.3ms inference, 0.0ms loss, 2.1ms postprocess per image
# Results saved to runs/detect/val3
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7c9407d76b30>
# ...

# %%
model.val(data="data-cfg/test_vv.yaml")
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/drive/.shortcut-targets-by-id/1cJcJ_IZb_6BgXKcitj-rgkK17xQwujX2/Master Thesis/ultralytics/Datasets/SAR-Ship/VV/labels.cache... 2635 images, 0 backgrounds, 0 corrupt: 100%|██████████| 2635/2635 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  99%|█████████▉| 164/165 [01:37<00:00,  3.87it/s]/usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 165/165 [01:38<00:00,  1.68it/s]
# ...

# %%
# CA

# %%
model=YOLO('runs/detect/train20/weights/best.pt')
model.val(data="data-cfg/test-hh.yaml")
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-CA summary (fused): 184 layers, 3108819 parameters, 0 gradients
# val: Scanning /content/drive/.shortcut-targets-by-id/1cJcJ_IZb_6BgXKcitj-rgkK17xQwujX2/Master Thesis/ultralytics/Datasets/SAR-Ship/HH/labels.cache... 17648 images, 0 backgrounds, 0 corrupt: 100%|██████████| 17648/17648 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1103/1103 [08:30<00:00,  2.16it/s]
#                    all      17648      21334      0.705      0.654      0.677      0.264
# Speed: 0.4ms preprocess, 4.1ms inference, 0.0ms loss, 2.0ms postprocess per image
# Results saved to runs/detect/val5
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7c940b66c580>
# ...

# %%
model.val(data="data-cfg/test-hv.yaml")
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/drive/.shortcut-targets-by-id/1cJcJ_IZb_6BgXKcitj-rgkK17xQwujX2/Master Thesis/ultralytics/Datasets/SAR-Ship/HV/labels.cache... 14713 images, 10 backgrounds, 0 corrupt: 100%|██████████| 14723/14723 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 921/921 [06:59<00:00,  2.20it/s]
#                    all      14723      17667      0.629      0.526      0.551      0.183
# Speed: 0.4ms preprocess, 4.2ms inference, 0.0ms loss, 2.1ms postprocess per image
# Results saved to runs/detect/val6
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7c940c065cf0>
# ...

# %%
model.val(data="data-cfg/test-vh.yaml")
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/drive/.shortcut-targets-by-id/1cJcJ_IZb_6BgXKcitj-rgkK17xQwujX2/Master Thesis/ultralytics/Datasets/SAR-Ship/VH/labels.cache... 3764 images, 0 backgrounds, 0 corrupt: 100%|██████████| 3764/3764 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 236/236 [01:46<00:00,  2.22it/s]
#                    all       3764       5608      0.621      0.518      0.536       0.19
# Speed: 0.5ms preprocess, 4.4ms inference, 0.0ms loss, 2.2ms postprocess per image
# Results saved to runs/detect/val7
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7c940669ad40>
# ...

# %%
model.val(data="data-cfg/test_vv.yaml")
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/drive/.shortcut-targets-by-id/1cJcJ_IZb_6BgXKcitj-rgkK17xQwujX2/Master Thesis/ultralytics/Datasets/SAR-Ship/VV/labels.cache... 2635 images, 0 backgrounds, 0 corrupt: 100%|██████████| 2635/2635 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 165/165 [01:24<00:00,  1.96it/s]
#                    all       2635       3892      0.777       0.69      0.741      0.293
# Speed: 0.4ms preprocess, 5.0ms inference, 0.0ms loss, 2.6ms postprocess per image
# Results saved to runs/detect/val8
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7c9407eaec50>
# ...

# %%
#ECA

# %%
model=YOLO('runs/detect/train21/weights/best.pt')
model.val(data="data-cfg/test-hh.yaml")
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-ECA summary (fused): 184 layers, 3005855 parameters, 0 gradients
# val: Scanning /content/drive/.shortcut-targets-by-id/1cJcJ_IZb_6BgXKcitj-rgkK17xQwujX2/Master Thesis/ultralytics/Datasets/SAR-Ship/HH/labels.cache... 17648 images, 0 backgrounds, 0 corrupt: 100%|██████████| 17648/17648 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1103/1103 [09:04<00:00,  2.03it/s]
#                    all      17648      21334      0.713      0.619      0.666      0.262
# Speed: 0.5ms preprocess, 4.3ms inference, 0.0ms loss, 2.2ms postprocess per image
# Results saved to runs/detect/val9
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7c94066cd450>
# ...

# %%
model.val(data="data-cfg/test-hv.yaml")
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/drive/.shortcut-targets-by-id/1cJcJ_IZb_6BgXKcitj-rgkK17xQwujX2/Master Thesis/ultralytics/Datasets/SAR-Ship/HV/labels.cache... 14713 images, 10 backgrounds, 0 corrupt: 100%|██████████| 14723/14723 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 921/921 [07:50<00:00,  1.96it/s]
#                    all      14723      17667      0.664      0.544      0.588      0.212
# Speed: 0.5ms preprocess, 4.4ms inference, 0.0ms loss, 2.3ms postprocess per image
# Results saved to runs/detect/val10
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7c940c09b430>
# ...

# %%
model=YOLO('runs/detect/train21/weights/best.pt')
model.val(data="data-cfg/test-vh.yaml")
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-ECA summary (fused): 184 layers, 3005855 parameters, 0 gradients
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 24.6MB/s]
# val: Scanning /content/drive/.shortcut-targets-by-id/1cJcJ_IZb_6BgXKcitj-rgkK17xQwujX2/Master Thesis/ultralytics/Datasets/SAR-Ship/VH/labels.cache... 3764 images, 0 backgrounds, 0 corrupt: 100%|██████████| 3764/3764 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 236/236 [02:22<00:00,  1.65it/s]
#                    all       3764       5608      0.608      0.466      0.499      0.182
# Speed: 0.3ms preprocess, 4.0ms inference, 0.0ms loss, 3.3ms postprocess per image
# Results saved to runs/detect/val12
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# ...

# %%
model.val(data="data-cfg/test_vv.yaml")
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/drive/.shortcut-targets-by-id/1cJcJ_IZb_6BgXKcitj-rgkK17xQwujX2/Master Thesis/ultralytics/Datasets/SAR-Ship/VV/labels.cache... 2635 images, 0 backgrounds, 0 corrupt: 100%|██████████| 2635/2635 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  99%|█████████▉| 164/165 [01:35<00:00,  3.64it/s]/usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 165/165 [01:36<00:00,  1.72it/s]
# ...

# %%
### Appendix

# %%
### Baseline

# %%
model=YOLO('runs/detect/train16/weights/best.pt')
model.val(data="data-cfg/test-hh.yaml")
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 18.3MB/s]
# val: Scanning /content/drive/.shortcut-targets-by-id/1cJcJ_IZb_6BgXKcitj-rgkK17xQwujX2/Master Thesis/ultralytics/Datasets/SAR-Ship/HH/labels.cache... 17648 images, 0 backgrounds, 0 corrupt: 100%|██████████| 17648/17648 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1103/1103 [3:17:24<00:00, 10.74s/it]
#                    all      17648      21334       0.22      0.126     0.0755     0.0239
# Speed: 4.4ms preprocess, 270.8ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to runs/detect/val
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# ...

# %%
model=YOLO('runs/detect/train16/weights/best.pt')
model.val(data="data-cfg/test-hv.yaml")
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients
# val: Scanning /content/drive/.shortcut-targets-by-id/1cJcJ_IZb_6BgXKcitj-rgkK17xQwujX2/Master Thesis/ultralytics/Datasets/SAR-Ship/HV/labels.cache... 14713 images, 10 backgrounds, 0 corrupt: 100%|██████████| 14723/14723 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 921/921 [2:48:23<00:00, 10.97s/it]
#                    all      14723      17667      0.187     0.0833     0.0687     0.0225
# Speed: 7.7ms preprocess, 289.8ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to runs/detect/val2
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7a84821ee7d0>
# ...

# %%
model=YOLO('runs/detect/train16/weights/best.pt')
model.val(data="data-cfg/test-vh.yaml")
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients
# val: Scanning /content/drive/.shortcut-targets-by-id/1cJcJ_IZb_6BgXKcitj-rgkK17xQwujX2/Master Thesis/ultralytics/Datasets/SAR-Ship/VH/labels.cache... 3764 images, 0 backgrounds, 0 corrupt: 100%|██████████| 3764/3764 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 236/236 [24:50<00:00,  6.32s/it]
#                    all       3764       5608      0.238     0.0808     0.0713      0.024
# Speed: 8.5ms preprocess, 327.0ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to runs/detect/val3
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7a848204dea0>
# ...

# %%
model=YOLO('runs/detect/train16/weights/best.pt')
model.val(data="data-cfg/test_vv.yaml")
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients
# val: Scanning /content/drive/.shortcut-targets-by-id/1cJcJ_IZb_6BgXKcitj-rgkK17xQwujX2/Master Thesis/ultralytics/Datasets/SAR-Ship/VV/labels.cache... 2635 images, 0 backgrounds, 0 corrupt: 100%|██████████| 2635/2635 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 165/165 [17:32<00:00,  6.38s/it]
#                    all       2635       3892      0.391      0.181      0.168     0.0549
# Speed: 8.6ms preprocess, 342.1ms inference, 0.0ms loss, 2.2ms postprocess per image
# Results saved to runs/detect/val4
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7a848b555510>
# ...

# %%
#CA

# %%
model=YOLO('runs/detect/train17/weights/best.pt')
model.val(data="data-cfg/test-hh.yaml")
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# YOLOv8n-CA summary (fused): 184 layers, 3108819 parameters, 0 gradients
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 23.6MB/s]
# val: Scanning /content/drive/.shortcut-targets-by-id/1cJcJ_IZb_6BgXKcitj-rgkK17xQwujX2/Master Thesis/ultralytics/Datasets/SAR-Ship/HH/labels.cache... 17648 images, 0 backgrounds, 0 corrupt: 100%|██████████| 17648/17648 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1103/1103 [09:56<00:00,  1.85it/s]
#                    all      17648      21334      0.195      0.141     0.0859     0.0277
# Speed: 0.2ms preprocess, 1.7ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to runs/detect/val5
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# ...

# %%
model.val(data="data-cfg/test-hv.yaml")
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# val: Scanning /content/drive/.shortcut-targets-by-id/1cJcJ_IZb_6BgXKcitj-rgkK17xQwujX2/Master Thesis/ultralytics/Datasets/SAR-Ship/HV/labels.cache... 14713 images, 10 backgrounds, 0 corrupt: 100%|██████████| 14723/14723 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 921/921 [04:46<00:00,  3.22it/s]
#                    all      14723      17667      0.158     0.0952     0.0568     0.0173
# Speed: 0.2ms preprocess, 1.7ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to runs/detect/val6
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7910221163b0>
# ...

# %%
model.val(data="data-cfg/test-vh.yaml")
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# val: Scanning /content/drive/.shortcut-targets-by-id/1cJcJ_IZb_6BgXKcitj-rgkK17xQwujX2/Master Thesis/ultralytics/Datasets/SAR-Ship/VH/labels.cache... 3764 images, 0 backgrounds, 0 corrupt: 100%|██████████| 3764/3764 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 236/236 [01:32<00:00,  2.55it/s]
#                    all       3764       5608      0.155     0.0836     0.0484     0.0137
# Speed: 0.2ms preprocess, 1.7ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to runs/detect/val7
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x79116925f6d0>
# ...

# %%
model.val(data="data-cfg/test_vv.yaml")
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# val: Scanning /content/drive/.shortcut-targets-by-id/1cJcJ_IZb_6BgXKcitj-rgkK17xQwujX2/Master Thesis/ultralytics/Datasets/SAR-Ship/VV/labels.cache... 2635 images, 0 backgrounds, 0 corrupt: 100%|██████████| 2635/2635 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 165/165 [01:08<00:00,  2.41it/s]
#                    all       2635       3892      0.372      0.194      0.163     0.0486
# Speed: 0.2ms preprocess, 1.7ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to runs/detect/val8
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x791013af2440>
# ...

# %%
#ECA
