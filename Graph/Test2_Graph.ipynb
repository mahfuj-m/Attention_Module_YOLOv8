# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import pandas as pd
import sys
# %cd ..
sys.path.append(os.path.join(os.getcwd(),'ultralytics/'))
# Out:
# /Users/mahfujurrahman/Desktop/Thesis/ultralytics
# /Users/mahfujurrahman/Desktop/Thesis/thesis/lib/python3.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from ultralytics import YOLO

# %%
model=YOLO('Graph/properties/Test 2/weights/best.pt')

# %%
model.info(detailed=False)

# %%
df=pd.read_csv('Graph/properties/Test 2/results.csv')

# %%
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['epoch', 'train/box_loss', 'train/cls_loss', 'train/dfl_loss',
#        'metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)',
#        'metrics/mAP50-95(B)', 'val/box_loss', 'val/cls_loss', 'val/dfl_loss',
#        'lr/pg0', 'lr/pg1', 'lr/pg2'],
#       dtype='object')

# %%
df.plot(x='epoch', y=['train/box_loss','val/box_loss' ], kind='line', marker='o', linestyle='-')

plt.ylabel('Bounding Box Loss')
plt.savefig('boxloss.png')

# %%
df.plot(x='epoch', y=['metrics/precision(B)','metrics/recall(B)'], kind='line', marker='o', linestyle='-')

plt.ylabel('value')
plt.savefig('precision-recall.png')

# %%
df.plot(x='epoch', y=['metrics/mAP50(B)','metrics/mAP50-95(B)'], kind='line', marker='o', linestyle='-')

plt.ylabel('value')
plt.savefig('map.png')

# %%
#### Model size
